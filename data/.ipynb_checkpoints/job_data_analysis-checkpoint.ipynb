# %%
# import necessay libraries
import pandas as pd
import numpy  as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 # import necessay libraries
# ----> 2 import pandas as pd
#       3 import numpy  as np
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~\anaconda3\lib\site-packages\pandas\compat\__init__.py:18
#      15 from typing import TYPE_CHECKING
#      17 from pandas._typing import F
# ---> 18 from pandas.compat.numpy import (
#      19     is_numpy_dev,
#      20     np_version_under1p21,
#      21 )
#      22 from pandas.compat.pyarrow import (
#      23     pa_version_under1p01,
#      24     pa_version_under2p0,
#    (...)
#      31     pa_version_under9p0,
#      32 )
#      34 if TYPE_CHECKING:
#
# File ~\anaconda3\lib\site-packages\pandas\compat\numpy\__init__.py:4
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File ~\anaconda3\lib\site-packages\pandas\util\__init__.py:2
#       1 # pyright: reportUnusedImport = false
# ----> 2 from pandas.util._decorators import (  # noqa:F401
#       3     Appender,
#       4     Substitution,
#       5     cache_readonly,
#       6 )
#       8 from pandas.core.util.hashing import (  # noqa:F401
#       9     hash_array,
#      10     hash_pandas_object,
#      11 )
#      14 def __getattr__(name):
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly
#      15 from pandas._typing import (
#      16     F,
#      17     T,
#      18 )
#      19 from pandas.util._exceptions import find_stack_level
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
data = pd.read_csv('job.csv')
data.shape
# Out:
# (4596, 7)

# %%
data.head()
# Out:
#                           job_title  \
# 0    Business Development Associate
# 1  IELTS/PTE/Spoken English Trainer
# 2                  Fashion Designer
# 3         Corporate Sales Executive
# 4           Junior Python Developer
#
#                                 company_name   location          start_date  \
# 0                             Break The Code     Mumbai  Starts Immediately
# 1               DePioneer Education Overseas      Delhi  Starts Immediately
# 2                           Valkyre Clothing     Mumbai  Starts Immediately
# 3  Kompass India Information Private Limited     Mumbai  Starts Immediately
# 4     Extension Technologies Private Limited  Faridabad  Starts Immediately
#
#                      ctc experience                                 posted
# 0  ₹ 2,00,000 - 3,00,000  0-1 years                             3 days ago
# 1  ₹ 3,00,000 - 3,50,000  0-2 years                             1 week ago
# 2  ₹ 3,00,000 - 3,50,000  0-2 years  3 days ago\n\n\nBe an early applicant
# 3  ₹ 2,00,000 - 4,00,000  0-5 years                            3 weeks ago
# 4  ₹ 2,40,000 - 3,60,000  0-2 years                            2 weeks ago

# %%
data.columns
# Out:
# Index(['job_title', 'company_name', 'location', 'start_date', 'ctc',
#        'experience', 'posted'],
#       dtype='str')

# %%
data.isnull().sum()
# Out:
# job_title       0
# company_name    0
# location        0
# start_date      0
# ctc             0
# experience      0
# posted          0
# dtype: int64

# %%
data['job_title'].duplicated().sum()
# Out:
# np.int64(2829)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4596 entries, 0 to 4595
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_title     4596 non-null   str
#  1   company_name  4596 non-null   str
#  2   location      4596 non-null   str
#  3   start_date    4596 non-null   str
#  4   ctc           4596 non-null   str
#  5   experience    4596 non-null   str
#  6   posted        4596 non-null   str
# dtypes: str(7)
# memory usage: 251.5 KB

# %%
data['ctc'].value_counts()
# Out:
# ctc
# ₹ 2,00,000 - 3,00,000      520
# ₹ 2,00,000                 274
# ₹ 2,00,000 - 2,50,000      249
# ₹ 2,00,000 - 2,40,000      205
# Competitive salary         202
#                           ...
# ₹ 50,40,000 - 64,80,000      1
# ₹ 21,60,000 - 36,00,000      1
# ₹ 2,20,000 - 4,25,000        1
# ₹ 17,00,000 - 25,00,000      1
# ₹ 24,00,000 - 30,00,000      1
# Name: count, Length: 487, dtype: int64

# %%
data['job_title'].value_counts()[:5]
# Out:
# job_title
# Business Development Executive    290
# Business Development Associate    129
# Graphic Designer                  126
# Sales Executive                    88
# Digital Marketing Executive        73
# Name: count, dtype: int64

# %%
data['ctc'].unique()
# Out:
# <StringArray>
# [  '₹ 2,00,000 - 3,00,000',   '₹ 3,00,000 - 3,50,000',
#    '₹ 2,00,000 - 4,00,000',   '₹ 2,40,000 - 3,60,000',
#    '₹ 2,40,000 - 3,00,000',   '₹ 2,00,000 - 2,50,000',
#    '₹ 2,52,000 - 4,00,000',  '₹ 7,00,000 - 10,00,000',
#    '₹ 5,00,000 - 8,00,000',   '₹ 4,00,000 - 7,00,000',
#  ...
#  '₹ 28,80,000 - 36,00,000',  '₹ 6,60,000 - 10,80,000',
#    '₹ 2,40,000 - 3,36,000',   '₹ 5,00,000 - 8,50,000',
#    '₹ 4,80,000 - 9,60,000', '₹ 50,40,000 - 64,80,000',
#  '₹ 21,60,000 - 36,00,000',   '₹ 2,20,000 - 4,25,000',
#  '₹ 17,00,000 - 25,00,000', '₹ 24,00,000 - 30,00,000']
# Length: 487, dtype: str

# %%
def clean_ctc(series):
    return (series
            .str.replace(r'[^0-9,]', '', regex=True)
            .str.replace(',', '', regex=False)
            .replace('', pd.NA)
           )

data['is_salary_disclosed'] = data['ctc'].ne('Competitive salary')
data['min_ctc'] = clean_ctc(data['ctc'].str.split('-').str[0])
data['max_ctc'] = clean_ctc(data['ctc'].str.split('-').str[-1])

# Optional: convert to numeric for calculations
data['min_ctc'] = pd.to_numeric(data['min_ctc'], errors='coerce')
data['max_ctc'] = pd.to_numeric(data['max_ctc'], errors='coerce')

# %%
data['experience'].value_counts()
# Out:
# experience
# 0-2 years      2730
# 0-5 years       758
# 1-3 years       335
# 0-1 years       201
# 4-6 years       163
# 0-3 years        47
# 7-10 years       47
# 1-2 years        44
# 1-5 years        43
# 2-5 years        42
# 3-5 years        38
# 0 years          37
# 4-5 years        19
# 2-4 years        16
# 1 year           15
# 1-4 years        13
# 0-4 years        10
# 2 years          10
# 2-3 years         9
# 10-15 years       8
# 3-4 years         3
# 3 years           2
# 4 years           1
# 6-10 years        1
# 5-7 years         1
# 2-10 years        1
# 3-6 years         1
# 3-7 years         1
# Name: count, dtype: int64

# %%
data['experience'] = data['experience'].str.replace(' years', "")
data['min_exp'] = clean_ctc(data['experience'].str.split('-').str[0])
data['max_exp'] = clean_ctc(data['experience'].str.split('-').str[-1])

# Optional: convert to numeric for calculations
data['min_exp'] = pd.to_numeric(data['min_exp'], errors='coerce')
data['max_exp'] = pd.to_numeric(data['max_exp'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4596 entries, 0 to 4595
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_title            4596 non-null   str
#  1   company_name         4596 non-null   str
#  2   location             4596 non-null   str
#  3   start_date           4596 non-null   str
#  4   ctc                  4596 non-null   str
#  5   experience           4596 non-null   str
#  6   posted               4596 non-null   str
#  7   is_salary_disclosed  4596 non-null   bool
#  8   min_ctc              4394 non-null   float64
#  9   max_ctc              4394 non-null   float64
#  10  min_exp              4596 non-null   int64
#  11  max_exp              4596 non-null   int64
# dtypes: bool(1), float64(2), int64(2), str(7)
# memory usage: 399.6 KB

# %%
data[data.isna().any(axis= 1)]
# Out:
#                            job_title               company_name   location  \
# 3989                  Java Developer  Leaguesol Private Limited  Hyderabad
# 3990                  Java Developer  Leaguesol Private Limited  Bangalore
# 3995                      Accountant             Freshleaf Teas   Ludhiana
# 3996                Graphic Designer             Freshleaf Teas   Ludhiana
# 4008              Operations Manager              R3 Consultant     Mumbai
# ...                              ...                        ...        ...
# 4591                   PHP Developer                     Unnati    Gurgaon
# 4592              Software Developer                     Unnati    Gurgaon
# 4593  Social Media Marketing Manager                     Unnati      Delhi
# 4594                Graphic Designer                     Unnati    Gurgaon
# 4595       Digital Marketing Manager                     Unnati      Delhi
#
#               start_date                 ctc experience       posted  \
# 3989  Starts Immediately  Competitive salary        4-6    1 day ago
# 3990  Starts Immediately  Competitive salary        4-6    1 day ago
# 3995  Starts Immediately  Competitive salary        0-1    1 day ago
# 3996  Starts Immediately  Competitive salary        0-1    1 day ago
# 4008  Starts Immediately  Competitive salary        4-6   2 days ago
# ...                  ...                 ...        ...          ...
# 4591  Starts Immediately  Competitive salary        3-5  3 weeks ago
# 4592  Starts Immediately  Competitive salary       2-10  3 weeks ago
# 4593  Starts Immediately  Competitive salary        3-4  3 weeks ago
# 4594  Starts Immediately  Competitive salary        3-6  3 weeks ago
# 4595  Starts Immediately  Competitive salary        3-7  3 weeks ago
#
#       is_salary_disclosed  min_ctc  max_ctc  min_exp  max_exp
# 3989                False      NaN      NaN        4        6
# 3990                False      NaN      NaN        4        6
# 3995                False      NaN      NaN        0        1
# 3996                False      NaN      NaN        0        1
# 4008                False      NaN      NaN        4        6
# ...                   ...      ...      ...      ...      ...
# 4591                False      NaN      NaN        3        5
# 4592                False      NaN      NaN        2       10
# 4593                False      NaN      NaN        3        4
# 4594                False      NaN      NaN        3        6
# 4595                False      NaN      NaN        3        7
#
# [202 rows x 12 columns]

# %% [markdown]
# ## "Competitive salary" means salary is undisclosed, so we keep min_ctc and max_ctc as missing values

# %%
# Extract only numeric part from "1 year", "3-5", "2-10" etc.
data['min_exp'] = data['experience'].str.extract(r'(\d+)').astype(float)
data['max_exp'] = data['experience'].str.extract(r'(\d+)-?(\d+)?')[1].fillna(data['min_exp']).astype(float)

# %%
data[data['ctc'] == 'Competitive salary']
# Out:
#                            job_title               company_name   location  \
# 3989                  Java Developer  Leaguesol Private Limited  Hyderabad
# 3990                  Java Developer  Leaguesol Private Limited  Bangalore
# 3995                      Accountant             Freshleaf Teas   Ludhiana
# 3996                Graphic Designer             Freshleaf Teas   Ludhiana
# 4008              Operations Manager              R3 Consultant     Mumbai
# ...                              ...                        ...        ...
# 4591                   PHP Developer                     Unnati    Gurgaon
# 4592              Software Developer                     Unnati    Gurgaon
# 4593  Social Media Marketing Manager                     Unnati      Delhi
# 4594                Graphic Designer                     Unnati    Gurgaon
# 4595       Digital Marketing Manager                     Unnati      Delhi
#
#               start_date                 ctc experience       posted  \
# 3989  Starts Immediately  Competitive salary        4-6    1 day ago
# 3990  Starts Immediately  Competitive salary        4-6    1 day ago
# 3995  Starts Immediately  Competitive salary        0-1    1 day ago
# 3996  Starts Immediately  Competitive salary        0-1    1 day ago
# 4008  Starts Immediately  Competitive salary        4-6   2 days ago
# ...                  ...                 ...        ...          ...
# 4591  Starts Immediately  Competitive salary        3-5  3 weeks ago
# 4592  Starts Immediately  Competitive salary       2-10  3 weeks ago
# 4593  Starts Immediately  Competitive salary        3-4  3 weeks ago
# 4594  Starts Immediately  Competitive salary        3-6  3 weeks ago
# 4595  Starts Immediately  Competitive salary        3-7  3 weeks ago
#
#       is_salary_disclosed  min_ctc  max_ctc  min_exp  max_exp
# 3989                False      NaN      NaN      4.0      6.0
# 3990                False      NaN      NaN      4.0      6.0
# 3995                False      NaN      NaN      0.0      1.0
# 3996                False      NaN      NaN      0.0      1.0
# 4008                False      NaN      NaN      4.0      6.0
# ...                   ...      ...      ...      ...      ...
# 4591                False      NaN      NaN      3.0      5.0
# 4592                False      NaN      NaN      2.0     10.0
# 4593                False      NaN      NaN      3.0      4.0
# 4594                False      NaN      NaN      3.0      6.0
# 4595                False      NaN      NaN      3.0      7.0
#
# [202 rows x 12 columns]

# %%
## keep undisclosed salaries as missing to avoid inventing values
data.loc[~data['is_salary_disclosed'], ['ctc', 'min_ctc', 'max_ctc']].head()
# Out:
#                      ctc  min_ctc  max_ctc
# 3989  Competitive salary      NaN      NaN
# 3990  Competitive salary      NaN      NaN
# 3995  Competitive salary      NaN      NaN
# 3996  Competitive salary      NaN      NaN
# 4008  Competitive salary      NaN      NaN

# %%
data.isnull().sum()
# Out:
# job_title                0
# company_name             0
# location                 0
# start_date               0
# ctc                      0
# experience               0
# posted                   0
# is_salary_disclosed      0
# min_ctc                202
# max_ctc                202
# min_exp                  0
# max_exp                  0
# dtype: int64

# %%
## convert float64 into nullable integer columns while preserving missing salaries
data['min_ctc'] = data['min_ctc'].astype('Int64')
data['max_ctc'] = data['max_ctc'].astype('Int64')
data['min_exp'] = data['min_exp'].astype('Int64')
data['max_exp'] = data['max_exp'].astype('Int64')

# %%
data.describe()
# Out:
#              min_ctc        max_ctc   min_exp   max_exp
# count         4394.0         4394.0    4596.0    4596.0
# mean   296914.152936  431667.908056   0.41188  2.881419
# std    242715.206669   430735.78192  1.187467   1.65727
# min           1440.0         1441.0       0.0       0.0
# 25%         200000.0       250000.0       0.0       2.0
# 50%         240000.0       350000.0       0.0       2.0
# 75%         300000.0       500000.0       0.0       4.0
# max        6000000.0     11750000.0      10.0      15.0

# %%
top_5_jobs = data['job_title'].value_counts().head(5)

plt.bar(x = top_5_jobs.index, height= top_5_jobs.values)
plt.title("Top 5 jobs")
plt.xlabel("position")
plt.ylabel("frequency of job")
plt.xticks(rotation = 90)
plt.show()

# %%
# instead we can use seaborn to make it more nice
import seaborn as sns

top_5_jobs = data['job_title'].value_counts().head(5).reset_index()
top_5_jobs.columns = ['job_title', 'frequency']

sns.barplot(data=top_5_jobs, x='job_title', y='frequency', palette='viridis')
plt.title("Top 5 Jobs")
plt.xlabel("Position")
plt.ylabel("Frequency of Job")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Manikanth Reddy\AppData\Local\Temp\ipykernel_10620\2418113649.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_5_jobs, x='job_title', y='frequency', palette='viridis')

# %%
data['posted'].unique()
# Out:
# <StringArray>
# [                              '3 days ago',
#                                '1 week ago',
#     '3 days ago\n\n\nBe an early applicant',
#                               '3 weeks ago',
#                               '2 weeks ago',
#      '1 day ago\n\n\nBe an early applicant',
#                                '4 days ago',
#                                '2 days ago',
#                                '6 days ago',
#                             'Few hours ago',
#                                     'Today',
#                                 '1 day ago',
#                                '5 days ago',
#       'Just now\n\n\nBe an early applicant',
#  'Few hours ago\n\n\nBe an early applicant',
#          'Today\n\n\nBe an early applicant',
#     '2 days ago\n\n\nBe an early applicant',
#     '5 days ago\n\n\nBe an early applicant',
#     '4 days ago\n\n\nBe an early applicant',
#     '6 days ago\n\n\nBe an early applicant',
#     '7 days ago\n\n\nBe an early applicant',
#     '1 week ago\n\n\nBe an early applicant',
#                                '7 days ago',
#    '3 weeks ago\n\n\nBe an early applicant',
#    '2 weeks ago\n\n\nBe an early applicant',
#                                  'Just now']
# Length: 26, dtype: str

# %%
data['posted'] = data["posted"].str.replace("\n\n\nBe an early applicant", "")
data['posted'].unique()
# Out:
# <StringArray>
# [   '3 days ago',    '1 week ago',   '3 weeks ago',   '2 weeks ago',
#      '1 day ago',    '4 days ago',    '2 days ago',    '6 days ago',
#  'Few hours ago',         'Today',    '5 days ago',      'Just now',
#     '7 days ago']
# Length: 13, dtype: str

# %%
listing_key = ['job_title', 'company_name', 'location']

exact_duplicate_mask = data.duplicated(keep='first')
repeated_listing_mask = data.duplicated(subset=listing_key, keep=False)
repost_candidate_mask = repeated_listing_mask & ~data.duplicated(keep=False)

data['is_noisy_duplicate'] = exact_duplicate_mask
data['is_repost_candidate'] = repost_candidate_mask

print(f"Exact duplicate rows to drop from summary stats: {data['is_noisy_duplicate'].sum()}")
print(f"Rows that look like reposted/refreshed listings: {data['is_repost_candidate'].sum()}")
# Out:
# Exact duplicate rows to drop from summary stats: 95
# Rows that look like reposted/refreshed listings: 180

# %%
data.loc[data['is_noisy_duplicate'], ['job_title', 'company_name', 'location', 'ctc', 'experience', 'posted']].head(10)
# Out:
#                              job_title  \
# 97      Business Development Executive
# 483              Back Office Executive
# 542     Business Development Associate
# 772          Corporate Sales Executive
# 929     Customer Acquisition Executive
# 942     Business Development Executive
# 1300                  Fashion Designer
# 1341  IELTS/PTE/Spoken English Trainer
# 1446              Operations Executive
# 1944   Video Editor & Graphic Designer
#
#                                    company_name               location  \
# 97              Plada Infotech Services Limited  Noida, Gurgaon, Delhi
# 483                              Suprem Service         Work from home
# 542                              Break The Code                 Mumbai
# 772   Kompass India Information Private Limited                 Mumbai
# 929              Sutra Services Private Limited                 Mumbai
# 942                       Saroj Education Group                  Delhi
# 1300                           Valkyre Clothing                 Mumbai
# 1341               DePioneer Education Overseas                  Delhi
# 1446                                      RoaDo              Bangalore
# 1944                         Brilliance Academy         Work from home
#
#                         ctc experience       posted
# 97    ₹ 2,00,000 - 4,00,000        0-2   1 week ago
# 483   ₹ 4,00,000 - 7,00,000        0-1    1 day ago
# 542   ₹ 2,00,000 - 3,00,000        0-1   3 days ago
# 772   ₹ 2,00,000 - 4,00,000        0-5  3 weeks ago
# 929   ₹ 2,00,000 - 3,50,000        0-2  3 weeks ago
# 942   ₹ 2,00,000 - 4,00,000        0-2  3 weeks ago
# 1300  ₹ 3,00,000 - 3,50,000        0-2   3 days ago
# 1341  ₹ 3,00,000 - 3,50,000        0-2   1 week ago
# 1446  ₹ 2,50,000 - 3,50,000        0-2   2 days ago
# 1944  ₹ 2,40,000 - 3,00,000        0-2   1 week ago

# %%
repost_candidates = (data.loc[data['is_repost_candidate']]
    .sort_values(listing_key + ['posted'])
    [['job_title', 'company_name', 'location', 'ctc', 'experience', 'posted']]
)

repost_candidates.head(10)
# Out:
#                job_title          company_name        location  \
# 679           Accountant            A1 Advance  Work from home
# 2388          Accountant            A1 Advance  Work from home
# 4250          Accountant  Aline HR Consultancy          Mumbai
# 4294          Accountant  Aline HR Consultancy          Mumbai
# 4400          Accountant    Gamut HR Solutions       Hyderabad
# 4046          Accountant    Gamut HR Solutions       Hyderabad
# 1180  Accounts Assistant          Tulsi Weaves         Chennai
# 1185  Accounts Assistant          Tulsi Weaves         Chennai
# 4347           Architect    Gamut HR Solutions       Hyderabad
# 4570           Architect    Gamut HR Solutions       Hyderabad
#
#                         ctc experience       posted
# 679   ₹ 4,00,000 - 7,00,000          0   1 week ago
# 2388  ₹ 5,00,000 - 7,00,000        0-5   1 week ago
# 4250  ₹ 2,64,000 - 3,00,000        1-3  2 weeks ago
# 4294  ₹ 2,64,000 - 3,00,000        1-3  3 weeks ago
# 4400  ₹ 3,00,000 - 4,20,000        4-6  3 weeks ago
# 4046  ₹ 3,00,000 - 3,24,000        4-6   6 days ago
# 1180  ₹ 2,00,000 - 2,16,000        0-2  3 weeks ago
# 1185             ₹ 2,40,000        0-2  3 weeks ago
# 4347  ₹ 3,00,000 - 4,20,000        4-6  3 weeks ago
# 4570  ₹ 2,16,000 - 2,40,000        1-3  3 weeks ago

# %%
analysis_data = data.loc[~data['is_noisy_duplicate']].copy()
print(f'Rows in original data: {len(data)}')
print(f'Rows used for summary stats: {len(analysis_data)}')
analysis_data.head()
# Out:
# Rows in original data: 4596
# Rows used for summary stats: 4501
#                           job_title  \
# 0    Business Development Associate
# 1  IELTS/PTE/Spoken English Trainer
# 2                  Fashion Designer
# 3         Corporate Sales Executive
# 4           Junior Python Developer
#
#                                 company_name   location          start_date  \
# 0                             Break The Code     Mumbai  Starts Immediately
# 1               DePioneer Education Overseas      Delhi  Starts Immediately
# 2                           Valkyre Clothing     Mumbai  Starts Immediately
# 3  Kompass India Information Private Limited     Mumbai  Starts Immediately
# 4     Extension Technologies Private Limited  Faridabad  Starts Immediately
#
#                      ctc experience       posted  is_salary_disclosed  \
# 0  ₹ 2,00,000 - 3,00,000        0-1   3 days ago                 True
# 1  ₹ 3,00,000 - 3,50,000        0-2   1 week ago                 True
# 2  ₹ 3,00,000 - 3,50,000        0-2   3 days ago                 True
# 3  ₹ 2,00,000 - 4,00,000        0-5  3 weeks ago                 True
# 4  ₹ 2,40,000 - 3,60,000        0-2  2 weeks ago                 True
#
#    min_ctc  max_ctc  min_exp  max_exp  is_noisy_duplicate  is_repost_candidate
# 0   200000   300000        0        1               False                False
# 1   300000   350000        0        2               False                False
# 2   300000   350000        0        2               False                False
# 3   200000   400000        0        5               False                False
# 4   240000   360000        0        2               False                False

# %%
def convert_to_days(posted):
    if pd.isna(posted):
        return pd.NA
    posted = str(posted).strip()
    if posted in ['Just now', 'Few hours ago', 'Today'] or 'hour' in posted:
        return 0
    if 'week' in posted:
        return int(posted.split()[0]) * 7
    if 'day' in posted:
        return int(posted.split()[0])
    return pd.NA

analysis_data['posted_days'] = analysis_data['posted'].apply(convert_to_days).astype('Int64')
analysis_data['is_remote'] = analysis_data['location'].str.contains('Work from home', case=False, na=False)
analysis_data['avg_ctc'] = ((analysis_data['min_ctc'] + analysis_data['max_ctc']) / 2).round(0).astype('Int64')

analysis_data[['posted', 'posted_days', 'is_remote', 'avg_ctc']].head()
# Out:
#         posted  posted_days  is_remote  avg_ctc
# 0   3 days ago            3      False   250000
# 1   1 week ago            7      False   325000
# 2   3 days ago            3      False   325000
# 3  3 weeks ago           21      False   300000
# 4  2 weeks ago           14      False   300000

# %%
analysis_data[['posted_days', 'is_remote', 'avg_ctc']].describe(include='all')
# Out:
#         posted_days is_remote        avg_ctc
# count        4501.0      4501         4331.0
# unique         <NA>         2           <NA>
# top            <NA>     False           <NA>
# freq           <NA>      3713           <NA>
# mean       11.74028       NaN  361883.345879
# std        7.156743       NaN  319820.580263
# min             0.0       NaN         1440.0
# 25%             7.0       NaN       228000.0
# 50%            14.0       NaN       295000.0
# 75%            21.0       NaN       400000.0
# max            21.0       NaN      6480000.0

# %%
top_10_jobs = analysis_data['job_title'].value_counts().head(10).reset_index()
top_10_jobs.columns = ['job_title', 'count']

plt.figure(figsize=(10, 6))
sns.barplot(data=top_10_jobs, x='count', y='job_title', hue='job_title', palette='viridis', legend=False)
plt.title('Top 10 Job Titles')
plt.xlabel('Number of Listings')
plt.ylabel('Job Title')
plt.tight_layout()
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
top_10_locations = data['location'].value_counts().head(10).reset_index()
top_10_locations.columns = ['location', 'count']

plt.figure(figsize=(10, 6))
sns.barplot(data=top_10_locations, x='count', y='location', hue='location', palette='magma', legend=False)
plt.title('Top 10 Hiring Locations')
plt.xlabel('Number of Listings')
plt.ylabel('Location')
plt.tight_layout()
plt.show()

# %%
top_10_companies = data['company_name'].value_counts().head(10).reset_index()
top_10_companies.columns = ['company_name', 'count']

plt.figure(figsize=(10, 6))
sns.barplot(data=top_10_companies, x='count', y='company_name', hue='company_name', palette='cubehelix', legend=False)
plt.title('Top 10 Hiring Companies')
plt.xlabel('Number of Listings')
plt.ylabel('Company')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature engineering

# %%
analysis_data['avg_ctc'].hist(bins = 50)
plt.yscale('log') # y-axis to a logarithmic scale
plt.title('Avg CTC distribution (log scale)')
# Out:
# Text(0.5, 1.0, 'Avg CTC distribution (log scale)')

# %%
# correlations
# analysis_data.info()
numeric_cols = analysis_data.select_dtypes(include= 'number').columns.tolist()
sns.heatmap(analysis_data[numeric_cols].corr(), annot= True)
# Out:
# <Axes: >

# %%
## outlier capping(winzorization): means limiting extreme values in your data to a set boundary, instead of removing them.
for col in ['avg_ctc', 'min_ctc', 'max_ctc']:
    upper = analysis_data[col].quantile(0.95)   ##takes 95% of the data
    analysis_data[col] = analysis_data[col].clip(upper= upper)
# categorical encoding prep
top_jobs = analysis_data['job_title'].value_counts().head(20)
analysis_data['job_title_top'] = analysis_data['job_title'].apply(lambda x:x if x in top_jobs else "other")

# %%
## split the data info train and test.
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(analysis_data, test_size= 0.2, random_state= 42)
train_df.to_csv(r'c:/Users/Manikanth Reddy/Documents/dev/Jobs/data/train.csv', index=False)
test_df.to_csv(r'c:/Users/Manikanth Reddy/Documents/dev/Jobs/data/test.csv', index=False)

# %% [markdown]
# ## model

# %%
from xgboost import XGBRegressor

# %%
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 test = pd.read_csv('test.csv')
#       2 train = pd.read_csv('train.csv')
#
# NameError: name 'pd' is not defined
